# %% [markdown]
# # STATISTICAL ANALYSIS
# ## Regression to explain bias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
periods = ['Q1', 'Q2', 'Q3', 'A1', 'A2']

# %%
data = {}
for period in periods:
    data[period] = pd.read_csv(f"results/{period}_rf.csv")

# %% [markdown]
# **Hypothesis Testing:**
#
# - After fitting the model, the coefficients and p-values for post_regulation (gamma) and N_analyst (lambda) are extracted.
# - The script checks if these coefficients are negative and if their p-values are less than 0.05 (indicating statistical significance).
# - It then prints whether each coefficient is both negative and statistically significant.

# %% [markdown]
# ## Regression for regulation of nov 2000

# %%
results = {}
for period in periods:
    data[period].rename(columns={'numest':'N_analyst'}, inplace=True)
    data[period]['post_regulation'] = np.where(data[period].Date> '2000-10', 1, 0)

    # alpha_i is the average bias_AF_ML for each permno.
    data[period]['alpha_i'] = data[period].groupby('permno')['bias_AF_ML'].transform('mean')
    
    # beta_t is the average bias_AF_ML for each Date.
    data[period]['beta_t'] = data[period].groupby('Date')['bias_AF_ML'].transform('mean')

    # Define the independent variables
    X = data[period][['alpha_i', 'beta_t', 'post_regulation']]
    # X = sm.add_constant(X)  # No: fixed aprte conisdered in alpha and beta 
    
    # Define the dependent variable
    y = data[period]['bias_AF_ML']
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Save the results
    results[period] = model.summary()
    
    # Print summary for each period
    print(f"Summary for {period}:")
    print(model.summary())

    # Hypothesis tests for gamma and lambda
    gamma_pvalue = model.pvalues['post_regulation']
    
    gamma_coefficient = model.params['post_regulation']
    
    
    print(f"\nHypothesis tests for {period}:")
    print(f"gamma (post_regulation) coefficient: {gamma_coefficient}, p-value: {gamma_pvalue}")
    
    gamma_significant = gamma_pvalue < 0.05
    
    print(f"Is gamma significant? {'Yes' if gamma_significant  else 'No'}")
# Out:
# Summary for Q1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.297
# Model:                            OLS   Adj. R-squared (uncentered):              0.297
# Method:                 Least Squares   F-statistic:                          1.253e+05
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        10:53:52   Log-Likelihood:                      1.0742e+06
# No. Observations:              888694   AIC:                                 -2.148e+06
# Df Residuals:                  888691   BIC:                                 -2.148e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9896      0.002    593.024      0.000       0.986       0.993
# beta_t              0.7897      0.007    114.115      0.000       0.776       0.803
# post_regulation    -0.0039      0.000    -37.076      0.000      -0.004      -0.004
# ==============================================================================
# Omnibus:                  3172879.614   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   44981208175143.336
# Skew:                          70.433   Prob(JB):                         0.00
# Kurtosis:                   34856.108   Cond. No.                         71.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q1:
# gamma (post_regulation) coefficient: -0.003871252561332245, p-value: 1.1457543132124327e-300
# Is gamma significant? Yes
# Summary for Q2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.256
# Model:                            OLS   Adj. R-squared (uncentered):              0.256
# Method:                 Least Squares   F-statistic:                          9.357e+04
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        10:53:54   Log-Likelihood:                      9.1916e+05
# No. Observations:              814051   AIC:                                 -1.838e+06
# Df Residuals:                  814048   BIC:                                 -1.838e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9887      0.002    510.487      0.000       0.985       0.993
# beta_t              0.7884      0.008    100.525      0.000       0.773       0.804
# post_regulation    -0.0047      0.000    -38.896      0.000      -0.005      -0.004
# ===============================================================================
# Omnibus:                  3697414.615   Durbin-Watson:                    1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   157403809765872.938
# Skew:                        -153.953   Prob(JB):                          0.00
# Kurtosis:                   68124.311   Cond. No.                          73.0
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q2:
# gamma (post_regulation) coefficient: -0.004657171514829292, p-value: 0.0
# Is gamma significant? Yes
# Summary for Q3:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.207
# Model:                            OLS   Adj. R-squared (uncentered):              0.207
# Method:                 Least Squares   F-statistic:                          6.545e+04
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        10:53:56   Log-Likelihood:                      8.6106e+05
# No. Observations:              750322   AIC:                                 -1.722e+06
# Df Residuals:                  750319   BIC:                                 -1.722e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9851      0.002    421.955      0.000       0.981       0.990
# beta_t              0.7763      0.008     92.072      0.000       0.760       0.793
# post_regulation    -0.0049      0.000    -39.434      0.000      -0.005      -0.005
# ===============================================================================
# Omnibus:                  3798980.399   Durbin-Watson:                    1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   345438935121999.750
# Skew:                        -225.022   Prob(JB):                          0.00
# Kurtosis:                  105117.697   Cond. No.                          77.9
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q3:
# gamma (post_regulation) coefficient: -0.0048812887371960465, p-value: 0.0
# Is gamma significant? Yes
# Summary for A1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.340
# Model:                            OLS   Adj. R-squared (uncentered):              0.340
# Method:                 Least Squares   F-statistic:                          1.569e+05
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        10:53:58   Log-Likelihood:                      7.8113e+05
# No. Observations:              913051   AIC:                                 -1.562e+06
# Df Residuals:                  913048   BIC:                                 -1.562e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9730      0.002    642.721      0.000       0.970       0.976
# beta_t              0.6185      0.005    133.170      0.000       0.609       0.628
# post_regulation    -0.0078      0.000    -49.961      0.000      -0.008      -0.007
# ==============================================================================
# Omnibus:                  2426710.348   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    2572519168165.404
# Skew:                          30.312   Prob(JB):                         0.00
# Kurtosis:                    8225.911   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A1:
# gamma (post_regulation) coefficient: -0.007792909002948772, p-value: 0.0
# Is gamma significant? Yes
# Summary for A2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.477
# Model:                            OLS   Adj. R-squared (uncentered):              0.477
# Method:                 Least Squares   F-statistic:                          2.353e+05
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        10:54:00   Log-Likelihood:                      1.1040e+06
# No. Observations:              775161   AIC:                                 -2.208e+06
# Df Residuals:                  775158   BIC:                                 -2.208e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9294      0.001    700.301      0.000       0.927       0.932
# beta_t              0.5062      0.003    189.118      0.000       0.501       0.511
# post_regulation    -0.0085      0.000    -83.770      0.000      -0.009      -0.008
# ==============================================================================
# Omnibus:                  1578691.547   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      70847429359.836
# Skew:                          15.931   Prob(JB):                         0.00
# Kurtosis:                    1483.714   Cond. No.                         32.2
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A2:
# gamma (post_regulation) coefficient: -0.008516931261354131, p-value: 0.0
# Is gamma significant? Yes

# %% [markdown]
# ## Regression for regulation of nov 2000 and N analyst

# %%
results = {}
for period in periods:
    data[period].rename(columns={'numest':'N_analyst'}, inplace=True)
    data[period]['post_regulation'] = np.where(data[period].Date> '2000-10', 1,0 )
    data[period]['alpha_i'] = data[period].groupby('permno')['bias_AF_ML'].transform('mean')
    data[period]['beta_t'] = data[period].groupby('Date')['bias_AF_ML'].transform('mean')

    # Define the independent variables
    X = data[period][['alpha_i', 'beta_t', 'N_analyst', 'post_regulation']]
    
    # Define the dependent variable
    y = data[period]['bias_AF_ML']
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Save the results
    results[period] = model.summary()
    
    # Print summary for each period
    print(f"Summary for {period}:")
    print(model.summary())

    # Hypothesis tests for gamma and lambda
    gamma_pvalue = model.pvalues['post_regulation']
    lambda_pvalue = model.pvalues['N_analyst']
    
    gamma_coefficient = model.params['post_regulation']
    lambda_coefficient = model.params['N_analyst']
    
    print(f"\nHypothesis tests for {period}:")
    print(f"gamma (post_regulation) coefficient: {gamma_coefficient}, p-value: {gamma_pvalue}")
    print(f"lambda (N_analyst) coefficient: {lambda_coefficient}, p-value: {lambda_pvalue}")
    
    gamma_significant = gamma_pvalue < 0.05
    lambda_significant = lambda_pvalue < 0.05
    
    print(f"Is gamma significant? {'Yes' if gamma_significant  else 'No'}")
    print(f"Is lambda significant? {'Yes' if lambda_significant else 'No'}\n")
# Out:
# Summary for Q1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.298
# Model:                            OLS   Adj. R-squared (uncentered):              0.298
# Method:                 Least Squares   F-statistic:                          9.414e+04
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:01:52   Log-Likelihood:                      1.0744e+06
# No. Observations:              888694   AIC:                                 -2.149e+06
# Df Residuals:                  888690   BIC:                                 -2.149e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9886      0.002    592.420      0.000       0.985       0.992
# beta_t              0.8029      0.007    115.658      0.000       0.789       0.817
# N_analyst          -0.0003   1.19e-05    -22.917      0.000      -0.000      -0.000
# post_regulation    -0.0018      0.000    -13.336      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                  3171946.689   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   45026866578003.938
# Skew:                          70.368   Prob(JB):                         0.00
# Kurtosis:                   34873.793   Cond. No.                         810.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q1:
# gamma (post_regulation) coefficient: -0.0018299973118823063, p-value: 1.4389564796542386e-40
# lambda (N_analyst) coefficient: -0.00027187372715798276, p-value: 3.41791662251654e-116
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for Q2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.257
# Model:                            OLS   Adj. R-squared (uncentered):              0.257
# Method:                 Least Squares   F-statistic:                          7.029e+04
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:01:54   Log-Likelihood:                      9.1933e+05
# No. Observations:              814051   AIC:                                 -1.839e+06
# Df Residuals:                  814047   BIC:                                 -1.839e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9878      0.002    509.963      0.000       0.984       0.992
# beta_t              0.7969      0.008    101.448      0.000       0.781       0.812
# N_analyst          -0.0003   1.52e-05    -18.275      0.000      -0.000      -0.000
# post_regulation    -0.0028      0.000    -17.367      0.000      -0.003      -0.002
# ===============================================================================
# Omnibus:                  3698705.604   Durbin-Watson:                    1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   157726669459943.844
# Skew:                        -154.137   Prob(JB):                          0.00
# Kurtosis:                   68194.139   Cond. No.                          731.
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q2:
# gamma (post_regulation) coefficient: -0.0027549985313048498, p-value: 1.5003482819132088e-67
# lambda (N_analyst) coefficient: -0.00027789371611197135, p-value: 1.3512099443305016e-74
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for Q3:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.208
# Model:                            OLS   Adj. R-squared (uncentered):              0.208
# Method:                 Least Squares   F-statistic:                          4.916e+04
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:01:56   Log-Likelihood:                      8.6118e+05
# No. Observations:              750322   AIC:                                 -1.722e+06
# Df Residuals:                  750318   BIC:                                 -1.722e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9840      0.002    421.384      0.000       0.979       0.989
# beta_t              0.7847      0.008     92.895      0.000       0.768       0.801
# N_analyst          -0.0003   1.68e-05    -15.597      0.000      -0.000      -0.000
# post_regulation    -0.0033      0.000    -20.307      0.000      -0.004      -0.003
# ===============================================================================
# Omnibus:                  3800269.450   Durbin-Watson:                    1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   346236411725652.312
# Skew:                        -225.296   Prob(JB):                          0.00
# Kurtosis:                  105238.960   Cond. No.                          710.
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q3:
# gamma (post_regulation) coefficient: -0.0032720450372694014, p-value: 1.1792798371017365e-91
# lambda (N_analyst) coefficient: -0.0002614377497183386, p-value: 7.739685561625258e-55
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for A1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.342
# Model:                            OLS   Adj. R-squared (uncentered):              0.342
# Method:                 Least Squares   F-statistic:                          1.188e+05
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:01:58   Log-Likelihood:                      7.8257e+05
# No. Observations:              913051   AIC:                                 -1.565e+06
# Df Residuals:                  913047   BIC:                                 -1.565e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9700      0.002    641.321      0.000       0.967       0.973
# beta_t              0.6850      0.005    142.705      0.000       0.676       0.694
# N_analyst          -0.0007   1.34e-05    -53.619      0.000      -0.001      -0.001
# post_regulation    -0.0030      0.000    -16.567      0.000      -0.003      -0.003
# ==============================================================================
# Omnibus:                  2422602.500   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    2585942412497.372
# Skew:                          30.168   Prob(JB):                         0.00
# Kurtosis:                    8247.340   Cond. No.                         463.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A1:
# gamma (post_regulation) coefficient: -0.002978142375174197, p-value: 1.2386669063584306e-61
# lambda (N_analyst) coefficient: -0.0007163117283902239, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for A2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.482
# Model:                            OLS   Adj. R-squared (uncentered):              0.482
# Method:                 Least Squares   F-statistic:                          1.804e+05
# Date:                Tue, 21 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:02:00   Log-Likelihood:                      1.1081e+06
# No. Observations:              775161   AIC:                                 -2.216e+06
# Df Residuals:                  775157   BIC:                                 -2.216e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9200      0.001    694.687      0.000       0.917       0.923
# beta_t              0.5845      0.003    208.765      0.000       0.579       0.590
# N_analyst          -0.0008   8.87e-06    -90.439      0.000      -0.001      -0.001
# post_regulation    -0.0034      0.000    -29.465      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                  1573396.292   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      72181135747.261
# Skew:                          15.791   Prob(JB):                         0.00
# Kurtosis:                    1497.599   Cond. No.                         436.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A2:
# gamma (post_regulation) coefficient: -0.0034126605984122534, p-value: 1.0247693363222258e-190
# lambda (N_analyst) coefficient: -0.0008026158621811678, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes

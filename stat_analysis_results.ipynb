# %% [markdown]
# # STATISTICAL ANALYSIS
# ## Regression to explain bias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
periods = ['Q1', 'Q2', 'Q3', 'A1', 'A2']

# %%
data = {}
for period in periods:
    data[period] = pd.read_csv(f"results/{period}_rf.csv")

# %% [markdown]
# **Hypothesis Testing:**
#
# - After fitting the model, the coefficients and p-values for post_regulation (gamma) and N_analyst (lambda) are extracted.
# - The script checks if these coefficients are negative and if their p-values are less than 0.05 (indicating statistical significance).
# - It then prints whether each coefficient is both negative and statistically significant.

# %% [markdown]
# ## Regression for regulation of nov 2000

# %%
results = {}
for period in periods:
    data[period].rename(columns={'numest':'N_analyst'}, inplace=True)
    data[period]['post_regulation'] = np.where(data[period].Date> '2000-10', 1, 0)

    # alpha_i is the average bias_AF_ML for each permno.
    data[period]['alpha_i'] = data[period].groupby('permno')['bias_AF_ML'].transform('mean')
    
    # beta_t is the average bias_AF_ML for each Date.
    data[period]['beta_t'] = data[period].groupby('Date')['bias_AF_ML'].transform('mean')

    # Define the independent variables
    X = data[period][['alpha_i', 'beta_t', 'post_regulation']]
    # X = sm.add_constant(X)  # No: fixed aprte conisdered in alpha and beta 
    
    # Define the dependent variable
    y = data[period]['bias_AF_ML']
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Save the results
    results[period] = model.summary()
    
    # Print summary for each period
    print(f"Summary for {period}:")
    print(model.summary())

    # Hypothesis tests for gamma and lambda
    gamma_pvalue = model.pvalues['post_regulation']
    
    gamma_coefficient = model.params['post_regulation']
    
    
    print(f"\nHypothesis tests for {period}:")
    print(f"gamma (post_regulation) coefficient: {gamma_coefficient}, p-value: {gamma_pvalue}")
    
    gamma_significant = gamma_pvalue < 0.05
    
    print(f"Is gamma significant? {'Yes' if gamma_significant  else 'No'}")
# Out:
# Summary for Q1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.294
# Model:                            OLS   Adj. R-squared (uncentered):              0.294
# Method:                 Least Squares   F-statistic:                          1.214e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:25   Log-Likelihood:                      2.2252e+06
# No. Observations:              874250   AIC:                                 -4.450e+06
# Df Residuals:                  874247   BIC:                                 -4.450e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9707      0.002    562.925      0.000       0.967       0.974
# beta_t              0.5771      0.005    112.731      0.000       0.567       0.587
# post_regulation    -0.0012   2.85e-05    -42.665      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                  2171642.871   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     454660518641.325
# Skew:                          25.791   Prob(JB):                         0.00
# Kurtosis:                    3535.524   Cond. No.                         199.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q1:
# gamma (post_regulation) coefficient: -0.001214013047963973, p-value: 0.0
# Is gamma significant? Yes
# Summary for Q2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.341
# Model:                            OLS   Adj. R-squared (uncentered):              0.341
# Method:                 Least Squares   F-statistic:                          1.324e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:28   Log-Likelihood:                      2.0566e+06
# No. Observations:              768154   AIC:                                 -4.113e+06
# Df Residuals:                  768151   BIC:                                 -4.113e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9502      0.002    552.058      0.000       0.947       0.954
# beta_t              0.6223      0.004    156.974      0.000       0.614       0.630
# post_regulation    -0.0020   2.81e-05    -72.704      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                  2418279.047   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    2435188271532.713
# Skew:                          49.173   Prob(JB):                         0.00
# Kurtosis:                    8725.081   Cond. No.                         169.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q2:
# gamma (post_regulation) coefficient: -0.0020438424881924645, p-value: 0.0
# Is gamma significant? Yes
# Summary for Q3:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.391
# Model:                            OLS   Adj. R-squared (uncentered):              0.391
# Method:                 Least Squares   F-statistic:                          1.473e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:30   Log-Likelihood:                      1.9249e+06
# No. Observations:              688193   AIC:                                 -3.850e+06
# Df Residuals:                  688190   BIC:                                 -3.850e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9402      0.002    561.716      0.000       0.937       0.943
# beta_t              0.6528      0.003    186.959      0.000       0.646       0.660
# post_regulation    -0.0024   2.67e-05    -91.565      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                  1685123.382   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     177957517893.855
# Skew:                          25.114   Prob(JB):                         0.00
# Kurtosis:                    2493.694   Cond. No.                         163.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q3:
# gamma (post_regulation) coefficient: -0.0024464147065783714, p-value: 0.0
# Is gamma significant? Yes
# Summary for A1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.361
# Model:                            OLS   Adj. R-squared (uncentered):              0.361
# Method:                 Least Squares   F-statistic:                          1.623e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:32   Log-Likelihood:                      1.1193e+06
# No. Observations:              860858   AIC:                                 -2.239e+06
# Df Residuals:                  860855   BIC:                                 -2.239e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9600      0.002    634.250      0.000       0.957       0.963
# beta_t              0.5531      0.004    141.919      0.000       0.546       0.561
# post_regulation    -0.0058      0.000    -55.583      0.000      -0.006      -0.006
# ==============================================================================
# Omnibus:                  2956107.732   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   11326846219169.762
# Skew:                          63.044   Prob(JB):                         0.00
# Kurtosis:                   17772.836   Cond. No.                         42.2
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A1:
# gamma (post_regulation) coefficient: -0.005762570124522212, p-value: 0.0
# Is gamma significant? Yes
# Summary for A2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.533
# Model:                            OLS   Adj. R-squared (uncentered):              0.533
# Method:                 Least Squares   F-statistic:                          2.520e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:34   Log-Likelihood:                      1.1953e+06
# No. Observations:              661723   AIC:                                 -2.391e+06
# Df Residuals:                  661720   BIC:                                 -2.390e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9239      0.001    712.397      0.000       0.921       0.926
# beta_t              0.5266      0.003    208.183      0.000       0.522       0.532
# post_regulation    -0.0071    7.5e-05    -95.117      0.000      -0.007      -0.007
# ==============================================================================
# Omnibus:                   987738.009   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4767791611.914
# Skew:                           8.277   Prob(JB):                         0.00
# Kurtosis:                     418.510   Cond. No.                         41.9
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A2:
# gamma (post_regulation) coefficient: -0.007136909889598083, p-value: 0.0
# Is gamma significant? Yes

# %% [markdown]
# ## Regression for regulation of nov 2000 and N analyst

# %%
results = {}
for period in periods:
    data[period].rename(columns={'numest':'N_analyst'}, inplace=True)
    data[period]['post_regulation'] = np.where(data[period].Date> '2000-10', 1,0 )
    data[period]['alpha_i'] = data[period].groupby('permno')['bias_AF_ML'].transform('mean')
    data[period]['beta_t'] = data[period].groupby('Date')['bias_AF_ML'].transform('mean')

    # Define the independent variables
    X = data[period][['alpha_i', 'beta_t', 'N_analyst', 'post_regulation']]
    
    # Define the dependent variable
    y = data[period]['bias_AF_ML']
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Save the results
    results[period] = model.summary()
    
    # Print summary for each period
    print(f"Summary for {period}:")
    print(model.summary())

    # Hypothesis tests for gamma and lambda
    gamma_pvalue = model.pvalues['post_regulation']
    lambda_pvalue = model.pvalues['N_analyst']
    
    gamma_coefficient = model.params['post_regulation']
    lambda_coefficient = model.params['N_analyst']
    
    print(f"\nHypothesis tests for {period}:")
    print(f"gamma (post_regulation) coefficient: {gamma_coefficient}, p-value: {gamma_pvalue}")
    print(f"lambda (N_analyst) coefficient: {lambda_coefficient}, p-value: {lambda_pvalue}")
    
    gamma_significant = gamma_pvalue < 0.05
    lambda_significant = lambda_pvalue < 0.05
    
    print(f"Is gamma significant? {'Yes' if gamma_significant  else 'No'}")
    print(f"Is lambda significant? {'Yes' if lambda_significant else 'No'}\n")
# Out:
# Summary for Q1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.296
# Model:                            OLS   Adj. R-squared (uncentered):              0.296
# Method:                 Least Squares   F-statistic:                          9.180e+04
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:36   Log-Likelihood:                      2.2263e+06
# No. Observations:              874250   AIC:                                 -4.452e+06
# Df Residuals:                  874246   BIC:                                 -4.452e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9658      0.002    559.642      0.000       0.962       0.969
# beta_t              0.6257      0.005    119.773      0.000       0.615       0.636
# N_analyst          -0.0001    3.2e-06    -45.380      0.000      -0.000      -0.000
# post_regulation    -0.0002   3.62e-05     -5.345      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                  2169840.343   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     456084182265.751
# Skew:                          25.732   Prob(JB):                         0.00
# Kurtosis:                    3541.053   Cond. No.                     2.30e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Hypothesis tests for Q1:
# gamma (post_regulation) coefficient: -0.0001936823297922472, p-value: 9.068050191106586e-08
# lambda (N_analyst) coefficient: -0.00014509214439046864, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for Q2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.343
# Model:                            OLS   Adj. R-squared (uncentered):              0.343
# Method:                 Least Squares   F-statistic:                          1.003e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:38   Log-Likelihood:                      2.0579e+06
# No. Observations:              768154   AIC:                                 -4.116e+06
# Df Residuals:                  768150   BIC:                                 -4.116e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9434      0.002    547.311      0.000       0.940       0.947
# beta_t              0.6538      0.004    163.206      0.000       0.646       0.662
# N_analyst          -0.0002   3.35e-06    -50.702      0.000      -0.000      -0.000
# post_regulation    -0.0009   3.54e-05    -26.741      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                  2419288.448   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    2455047658595.908
# Skew:                          49.229   Prob(JB):                         0.00
# Kurtosis:                    8760.578   Cond. No.                     1.72e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.72e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Hypothesis tests for Q2:
# gamma (post_regulation) coefficient: -0.0009474185481092983, p-value: 1.8741325060192385e-157
# lambda (N_analyst) coefficient: -0.00016977595402520117, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for Q3:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.393
# Model:                            OLS   Adj. R-squared (uncentered):              0.393
# Method:                 Least Squares   F-statistic:                          1.115e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:40   Log-Likelihood:                      1.9261e+06
# No. Observations:              688193   AIC:                                 -3.852e+06
# Df Residuals:                  688189   BIC:                                 -3.852e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9333      0.002    556.655      0.000       0.930       0.937
# beta_t              0.6763      0.004    192.227      0.000       0.669       0.683
# N_analyst          -0.0002   3.34e-06    -49.015      0.000      -0.000      -0.000
# post_regulation    -0.0015   3.33e-05    -44.201      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                  1684637.563   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     178958951167.147
# Skew:                          25.092   Prob(JB):                         0.00
# Kurtosis:                    2500.696   Cond. No.                     1.51e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Hypothesis tests for Q3:
# gamma (post_regulation) coefficient: -0.0014709268986095839, p-value: 0.0
# lambda (N_analyst) coefficient: -0.00016381771874687036, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for A1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.364
# Model:                            OLS   Adj. R-squared (uncentered):              0.364
# Method:                 Least Squares   F-statistic:                          1.234e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:42   Log-Likelihood:                      1.1214e+06
# No. Observations:              860858   AIC:                                 -2.243e+06
# Df Residuals:                  860854   BIC:                                 -2.243e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9541      0.002    630.745      0.000       0.951       0.957
# beta_t              0.6335      0.004    155.439      0.000       0.626       0.642
# N_analyst          -0.0006   8.85e-06    -65.720      0.000      -0.001      -0.001
# post_regulation    -0.0020      0.000    -16.565      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                  2959490.701   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   11503285337823.727
# Skew:                          63.258   Prob(JB):                         0.00
# Kurtosis:                   17910.707   Cond. No.                         602.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A1:
# gamma (post_regulation) coefficient: -0.001962663811726466, p-value: 1.2748114473127282e-61
# lambda (N_analyst) coefficient: -0.0005819010072204922, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for A2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.540
# Model:                            OLS   Adj. R-squared (uncentered):              0.540
# Method:                 Least Squares   F-statistic:                          1.942e+05
# Date:                Mon, 27 May 2024   Prob (F-statistic):                        0.00
# Time:                        11:38:44   Log-Likelihood:                      1.2000e+06
# No. Observations:              661723   AIC:                                 -2.400e+06
# Df Residuals:                  661719   BIC:                                 -2.400e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9119      0.001    705.036      0.000       0.909       0.914
# beta_t              0.6049      0.003    229.543      0.000       0.600       0.610
# N_analyst          -0.0006   6.29e-06    -98.055      0.000      -0.001      -0.001
# post_regulation    -0.0030   8.54e-05    -35.646      0.000      -0.003      -0.003
# ==============================================================================
# Omnibus:                   982595.350   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4973434712.598
# Skew:                           8.167   Prob(JB):                         0.00
# Kurtosis:                     427.399   Cond. No.                         582.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A2:
# gamma (post_regulation) coefficient: -0.0030439112761271926, p-value: 4.9231514600060236e-278
# lambda (N_analyst) coefficient: -0.0006167425093893915, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
